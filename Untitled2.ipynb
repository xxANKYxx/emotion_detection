# %%
import pandas as pd
import numpy as np
x=pd.read_csv('/content/drive/My Drive/Colab Notebooks/emotion/fer2013.csv')

# %%
import cv2
#train_data=data.iloc[1:28708]

# %%
#test_data=data.iloc[28709:28711]

# %%
from keras.models import Sequential
from keras.layers import Dense,Conv2D,Flatten,Dropout
from keras.optimizers import Adam
from keras.layers import MaxPooling2D
from keras.preprocessing.image import ImageDataGenerator
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline
import os
from keras.layers import Dense, Convolution2D, UpSampling2D, MaxPooling2D, ZeroPadding2D, Flatten, Dropout, Reshape
from keras.models import Sequential
from keras.utils import np_utils
# Out:
# Using TensorFlow backend.

# %%
data = x.values
y = data[:, 0]
pixels = data[:, 1]

# %%
X = np.zeros((pixels.shape[0], 48*48))

for ix in range(X.shape[0]):
    p = pixels[ix].split(' ')
    for iy in range(X.shape[1]):
        X[ix, iy] = int(p[iy])

# %%
x = X

# %%
for ix in range(2):
    plt.figure(ix)
    plt.imshow(x[ix].reshape((48, 48)), interpolation='none', cmap='gray')
plt.show()

# %%
x=x/255
X_train=x[0:28710,:]
Y_train=y[0:28710]
X_crossval=x[28710:32300,:]
Y_crossval=y[28710:32300]

# %%
X_train = X_train.reshape((X_train.shape[0], 48 , 48, 1 ))
X_crossval = X_crossval.reshape((X_crossval.shape[0],48, 48,1))

# %%
y_ = np_utils.to_categorical(y, 7)

# %%
Y_train = y_[:28710]
Y_crossval = y_[28710:32300]
print (X_crossval.shape, Y_crossval.shape)
# Out:
# (3590, 48, 48, 1) (3590, 7)

# %%
datagenrated=ImageDataGenerator(rotation_range=10,width_shift_range=0.1,height_shift_range=0.1)
datagenrated.fit(X_train)

# %%
from keras.callbacks import ReduceLROnPlateau
lr_reduce = ReduceLROnPlateau(monitor='val_acc', factor=0.1, epsilon=0.0001, patience=1, verbose=1)
# Out:
# /usr/local/lib/python3.6/dist-packages/keras/callbacks/callbacks.py:998: UserWarning: `epsilon` argument is deprecated and will be removed, use `min_delta` instead.
#   warnings.warn('`epsilon` argument is deprecated and '

# %%
from keras.layers import Dense , Activation
from keras.layers import Dropout
from keras.layers import Flatten
from keras.constraints import maxnorm
from keras.optimizers import SGD , Adam
from keras.layers import Conv2D , BatchNormalization
from keras.layers import MaxPooling2D
from keras.utils import np_utils
from keras.backend import common as K
K.set_image_dim_ordering('th')

# %%
model = Sequential()
model.add(Conv2D(32, kernel_size=(3, 3), activation='relu', input_shape=(48,48,1)))
model.add(Conv2D(64, kernel_size=(3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))
model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))
model.add(Flatten())
model.add(Dense(1024, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(7, activation='softmax'))

# %%
model.compile(loss='categorical_crossentropy',optimizer=Adam(lr=0.0001, decay=1e-6),metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_1 (Conv2D)            (None, 46, 46, 32)        320
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 44, 44, 64)        18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 22, 22, 64)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 22, 22, 64)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 20, 20, 128)       73856
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 10, 10, 128)       0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 8, 8, 128)         147584
# ...

# %%
batch_size = 128
epochs = 14

model.compile(loss='binary_crossentropy', optimizer='adam' , metrics=['accuracy'])
steps_per_epoch = len(X) // batch_size
validation_steps = len((X_crossval, Y_crossval)) // batch_size

# %%
history = model.fit_generator(datagenrated.flow(X_train, Y_train, batch_size=batch_size),
                    steps_per_epoch=X.shape[0] // batch_size,
                    callbacks=[lr_reduce],
                    validation_data=(X_crossval, Y_crossval),
                    epochs = epochs, verbose = 2)
# Out:
# Epoch 1/14
#  - 26s - loss: 0.3821 - accuracy: 0.8575 - val_loss: 0.3552 - val_accuracy: 0.8617
# Epoch 2/14
# /usr/local/lib/python3.6/dist-packages/keras/callbacks/callbacks.py:1042: RuntimeWarning: Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: val_loss,val_accuracy,loss,accuracy,lr
#   (self.monitor, ','.join(list(logs.keys()))), RuntimeWarning
#  - 19s - loss: 0.3448 - accuracy: 0.8666 - val_loss: 0.2991 - val_accuracy: 0.8814
# Epoch 3/14
#  - 19s - loss: 0.3098 - accuracy: 0.8770 - val_loss: 0.2809 - val_accuracy: 0.8868
# Epoch 4/14
#  - 19s - loss: 0.2945 - accuracy: 0.8816 - val_loss: 0.2711 - val_accuracy: 0.8909
# Epoch 5/14
#  - 20s - loss: 0.2827 - accuracy: 0.8855 - val_loss: 0.2640 - val_accuracy: 0.8935
# Epoch 6/14
#  - 19s - loss: 0.2771 - accuracy: 0.8875 - val_loss: 0.2590 - val_accuracy: 0.8932
# Epoch 7/14
#  - 19s - loss: 0.2712 - accuracy: 0.8897 - val_loss: 0.2519 - val_accuracy: 0.8979
# Epoch 8/14
# ...

# %%
weights = model.get_weights()

# %%
np.save('my_model_weigths',weights)

# %%
model.save('my_model.h5')

# %%
#####################
####opencv###########
#####################

# %%
res_dtct={0:"angry",1:"disgusted",2:"Fearful",3:"happy",4:"neutral",5:"sad",6:"surprised",}

# %%
import numpy as np
maxterm=0
model=load_model('my_model.h5')
res_dict={0:"angry",1:"disgusted",2:"Fearful",3:"happy",4:"neutral",5:"sad",6:"surprised",}

face_cascade = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')
cap = cv2.VideoCapture(0)
while (cap.isOpened()):
    ret, frame = cap.read()
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray, scaleFactor=1.5, minNeighbors=5)
    for (x, y, w, h) in faces:
        print(x, y, w, h)
        roi_gray = gray[y:y + h, x:x + w]
        roi_color = frame[y:y + h, x:x + w]
        cropped_img=np.expand_dims(np.expand_dims(cv2.resize(roi_gray, (48, 48)), -1), 0)
        emotion_prediction = model.predict(cropped_img)
        maxterm = int(np.argmax(emotion_prediction))
        # color = (255,0,0) #BGR
        # stroke = 2
        # cv2.rectangle(frame,(x,y),(x+w,y+h),color,stroke )

    font = cv2.FONT_HERSHEY_SIMPLEX
    cv2.putText(frame, res_dict[maxterm], (15, 25), font, 1, color=(255, 0, 0), thickness=1)
    cv2.imshow('frame', frame)

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break
cap.release()
cv2.destroyAllWindows()
